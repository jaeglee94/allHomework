# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
file = os.path.join("..","Team9","Datasets","SalesByModel.xlsx")
file2 = os.path.join("..","Team9","Datasets","10332_alt_fueling_stations_fuel.xlsx")

df = pd.read_excel(file)
charge = pd.read_excel(file2)
charge = charge[["Year","Total***"]]
charge=charge.iloc[7:26]

# %%
charge
# Out:
#     Year  Total***
# 7   1999    6056.0
# 8   2000    5205.0
# 9   2001    5542.0
# 10  2002    5741.0
# 11  2003    6230.0
# 12  2004    5720.0
# 13  2005    5164.0
# 14  2006    5091.0
# 15  2007    5551.0
# 16  2008    5756.0
# 17  2009    6411.0
# 18  2010    6912.0
# 19  2011   10071.0
# 20  2012   20498.0
# 21  2013   27159.0
# 22  2014   33805.0
# 23  2015   39963.0
# 24  2016   51398.0
# 25  2017   60053.0

# %%
years = df.columns.values
years = years[2:len(years)]
totals = df.iloc[112,2:len(df.columns)]
runTotal = df.iloc[113,2:len(df.columns)]
cleanType = pd.DataFrame({"year":years,"vehiclesSold":totals,"runningTotal":runTotal}).reset_index()
cleanType=cleanType.drop(labels="index",axis=1)
cleanType
# Out:
#     year vehiclesSold runningTotal
# 0   1999           17           17
# 1   2000         9350         9367
# 2   2001        20282        29649
# 3   2002        36035        65684
# 4   2003        47600       113284
# 5   2004        84199       197483
# 6   2005       209711       407194
# 7   2006       252636       659830
# 8   2007       352274   1.0121e+06
# 9   2008       312386  1.32449e+06
# 10  2009       290271  1.61476e+06
# 11  2010       274210  1.88897e+06
# 12  2011       284076  2.17305e+06
# 13  2012       488047  2.66109e+06
# 14  2013       592231  3.25332e+06
# 15  2014       570945  3.82427e+06
# 16  2015       498327   4.3226e+06
# 17  2016       506516  4.82911e+06
# 18  2017       565930  5.39504e+06

# %%
cleanType.plot(kind="line",x="year",y="vehiclesSold")
cleanType.plot(kind="line",x="year",y="runningTotal")
charge.plot(kind="line",x="Year",y="Total***")

# %%
test = os.path.join("..","Team9","Datasets","Elec_StationsbyState_Year.csv")
testDF = pd.read_csv(test)
testDF=testDF.drop(axis=1,columns="Unnamed: 0")
testDFgroup = testDF.groupby(by="State")
testDFgroup.count()
# Out:
#        Date_Opened  Access_Type   Lat   Lng
# State
# AK              15           15    15    15
# AL             142          142   142   142
# AR              67           67    67    67
# AZ             147          147   147   147
# CA            2166         2166  2166  2166
# CO             294          294   294   294
# CT             294          294   294   294
# DC              54           54    54    54
# DE              30           30    30    30
# FL             645          645   645   645
# GA             334          334   334   334
# HI             210          210   210   210
# IA              91           91    91    91
# ID              78           78    78    78
# IL             296          296   296   296
# IN             160          160   160   160
# KS              78           78    78    78
# KY              91           91    91    91
# LA              95           95    95    95
# MA             222          222   222   222
# ...
