# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# # Print the city count to confirm sufficient count
len(cities)
# Out:
# 619

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
cityList = pd.DataFrame(cities,columns={"cityName":cities})
cityList["longitude"] = ""
cityList["latitude"] = ""
cityList["temperature"] = ""
cityList["humidity"] = ""
cityList["cloudiness"] = ""
cityList["windSpeed"] = ""

url = "http://api.openweathermap.org/data/2.5/weather?"

for index, row in cityList.iterrows():
    parameters = {"q":row["cityName"],"appid":api_key, "units":"imperial"}
    result = requests.get(url,params=parameters).json()
    try:
        print("Processing Record {} | {}".format(index,row["cityName"]))
        cityList.loc[index,"latitude"] = result["coord"]["lat"]
        cityList.loc[index,"longitude"] = result["coord"]["lon"]
        cityList.loc[index,"temperature"] = result["main"]["temp_max"]
        cityList.loc[index,"humidity"] = result["main"]["humidity"]
        cityList.loc[index,"cloudiness"] = result["clouds"]["all"]
        cityList.loc[index,"windSpeed"] = result["wind"]["speed"]
    except:
        print("City not found.  Skipping...")
    time.sleep(2)

print("---------------------------\n   Data retrieval Complete\n---------------------------")
    
cityList.head()
# Out:
# Processing Record 0 | chuy
# Processing Record 1 | yakeshi
# Processing Record 2 | guerrero negro
# Processing Record 3 | hilo
# Processing Record 4 | baylo
# Processing Record 5 | saint-joseph
# Processing Record 6 | new norfolk
# Processing Record 7 | ushuaia
# Processing Record 8 | hermanus
# Processing Record 9 | kieta
# Processing Record 10 | port-gentil
# Processing Record 11 | alvorada
# Processing Record 12 | bredasdorp
# Processing Record 13 | abu kamal
# Processing Record 14 | punta arenas
# Processing Record 15 | kapaa
# Processing Record 16 | ilulissat
# Processing Record 17 | lishui
# Processing Record 18 | mataura
# Processing Record 19 | busselton
# Processing Record 20 | luwuk
# Processing Record 21 | jamestown
# Processing Record 22 | rocky mountain house
# Processing Record 23 | kirchheim
# Processing Record 24 | maneromango
# Processing Record 25 | qaanaaq
# Processing Record 26 | aykhal
# Processing Record 27 | rawson
# Processing Record 28 | laguna
# Processing Record 29 | ponta do sol
# Processing Record 30 | upernavik
# Processing Record 31 | viru
# Processing Record 32 | ciudad bolivar
# Processing Record 33 | sibolga
# Processing Record 34 | vilhena
# Processing Record 35 | albany
# Processing Record 36 | tuatapere
# Processing Record 37 | nikolskoye
# Processing Record 38 | kanniyakumari
# Processing Record 39 | korla
# City not found.  Skipping...
# Processing Record 40 | humaita
# Processing Record 41 | tuktoyaktuk
# Processing Record 42 | chino valley
# Processing Record 43 | kodiak
# Processing Record 44 | ribeira grande
# Processing Record 45 | tual
# Processing Record 46 | macas
# Processing Record 47 | kaitangata
# Processing Record 48 | araguaina
# Processing Record 49 | lagoa
# Processing Record 50 | faanui
# Processing Record 51 | mahajanga
# Processing Record 52 | half moon bay
# Processing Record 53 | pueblo nuevo
# Processing Record 54 | pisco
# Processing Record 55 | rurrenabaque
# Processing Record 56 | sao felix do xingu
# Processing Record 57 | maceio
# Processing Record 58 | yerbogachen
# Processing Record 59 | kruisfontein
# Processing Record 60 | east london
# Processing Record 61 | almaznyy
# Processing Record 62 | vaini
# Processing Record 63 | briceni
# Processing Record 64 | quetzaltepec
# City not found.  Skipping...
# Processing Record 65 | karratha
# Processing Record 66 | ziro
# Processing Record 67 | erenhot
# Processing Record 68 | bac lieu
# City not found.  Skipping...
# Processing Record 69 | carnarvon
# Processing Record 70 | tanggu
# City not found.  Skipping...
# Processing Record 71 | barcelos
# Processing Record 72 | khatanga
# Processing Record 73 | rikitea
# Processing Record 74 | akyab
# City not found.  Skipping...
# Processing Record 75 | gat
# Processing Record 76 | belushya guba
# City not found.  Skipping...
# Processing Record 77 | norman wells
# Processing Record 78 | henties bay
# Processing Record 79 | bluff
# Processing Record 80 | arraial do cabo
# Processing Record 81 | pankovka
# Processing Record 82 | ahipara
# Processing Record 83 | port lincoln
# Processing Record 84 | mahebourg
# Processing Record 85 | bugiri
# Processing Record 86 | port elizabeth
# Processing Record 87 | govindgarh
# Processing Record 88 | bambous virieux
# Processing Record 89 | taolanaro
# City not found.  Skipping...
# Processing Record 90 | kunashak
# Processing Record 91 | ngukurr
# City not found.  Skipping...
# Processing Record 92 | saint-philippe
# Processing Record 93 | te anau
# Processing Record 94 | lavrentiya
# Processing Record 95 | nizhneyansk
# City not found.  Skipping...
# Processing Record 96 | cape town
# Processing Record 97 | attawapiskat
# City not found.  Skipping...
# Processing Record 98 | broome
# Processing Record 99 | kuppam
# Processing Record 100 | yarada
# Processing Record 101 | airai
# Processing Record 102 | atuona
# Processing Record 103 | tiksi
# Processing Record 104 | tokzar
# City not found.  Skipping...
# Processing Record 105 | acara
# City not found.  Skipping...
# Processing Record 106 | port-cartier
# Processing Record 107 | pachino
# Processing Record 108 | zhezkazgan
# Processing Record 109 | antequera
# Processing Record 110 | santa maria
# Processing Record 111 | fairbanks
# Processing Record 112 | rexburg
# Processing Record 113 | barentsburg
# City not found.  Skipping...
# Processing Record 114 | collie
# Processing Record 115 | okato
# Processing Record 116 | georgetown
# Processing Record 117 | lompoc
# Processing Record 118 | cidreira
# Processing Record 119 | san felipe
# Processing Record 120 | taltal
# Processing Record 121 | cabo san lucas
# Processing Record 122 | garowe
# Processing Record 123 | prince george
# Processing Record 124 | amderma
# City not found.  Skipping...
# Processing Record 125 | torbay
# Processing Record 126 | thompson
# Processing Record 127 | istok
# Processing Record 128 | imbituba
# Processing Record 129 | prince rupert
# Processing Record 130 | luba
# Processing Record 131 | teguldet
# Processing Record 132 | sovetskiy
# Processing Record 133 | bubaque
# Processing Record 134 | cherskiy
# Processing Record 135 | port alfred
# Processing Record 136 | butaritari
# Processing Record 137 | yar-sale
# Processing Record 138 | tabiauea
# City not found.  Skipping...
# Processing Record 139 | elat
# Processing Record 140 | tubruq
# City not found.  Skipping...
# Processing Record 141 | kem
# Processing Record 142 | ust-nera
# Processing Record 143 | avarua
# Processing Record 144 | hobart
# Processing Record 145 | mujiayingzi
# Processing Record 146 | tasiilaq
# Processing Record 147 | komsomolskiy
# Processing Record 148 | caarapo
# Processing Record 149 | yuzhno-yeniseyskiy
# City not found.  Skipping...
# Processing Record 150 | puerto madero
# Processing Record 151 | gewane
# Processing Record 152 | leua
# Processing Record 153 | saskylakh
# Processing Record 154 | hithadhoo
# Processing Record 155 | cam ranh
# Processing Record 156 | preston
# Processing Record 157 | ponta delgada
# Processing Record 158 | san cristobal
# Processing Record 159 | lensk
# Processing Record 160 | riyadh
# Processing Record 161 | monte cristi
# City not found.  Skipping...
# Processing Record 162 | tezu
# Processing Record 163 | antalaha
# Processing Record 164 | iqaluit
# Processing Record 165 | meulaboh
# Processing Record 166 | barrow
# Processing Record 167 | san rafael
# Processing Record 168 | ewa beach
# Processing Record 169 | aswan
# Processing Record 170 | izumo
# Processing Record 171 | aklavik
# Processing Record 172 | saryagash
# Processing Record 173 | poplar bluff
# Processing Record 174 | crixas
# Processing Record 175 | newala
# Processing Record 176 | marang
# City not found.  Skipping...
# Processing Record 177 | bolungarvik
# City not found.  Skipping...
# Processing Record 178 | sitka
# Processing Record 179 | buraydah
# Processing Record 180 | vaitupu
# City not found.  Skipping...
# Processing Record 181 | hasaki
# Processing Record 182 | andenes
# City not found.  Skipping...
# Processing Record 183 | dikson
# Processing Record 184 | boke
# Processing Record 185 | cozumel
# City not found.  Skipping...
# Processing Record 186 | perth
# Processing Record 187 | illoqqortoormiut
# City not found.  Skipping...
# Processing Record 188 | arman
# Processing Record 189 | castro
# Processing Record 190 | saint george
# Processing Record 191 | luderitz
# Processing Record 192 | baghdad
# Processing Record 193 | nuristan
# Processing Record 194 | piacabucu
# Processing Record 195 | saint anthony
# Processing Record 196 | bethel
# Processing Record 197 | puerto ayora
# Processing Record 198 | tahlequah
# Processing Record 199 | morgan city
# Processing Record 200 | shenjiamen
# Processing Record 201 | esperance
# Processing Record 202 | jadu
# Processing Record 203 | tabuk
# Processing Record 204 | mareeba
# Processing Record 205 | sentyabrskiy
# City not found.  Skipping...
# Processing Record 206 | knysna
# Processing Record 207 | souillac
# Processing Record 208 | bozoum
# Processing Record 209 | seoul
# Processing Record 210 | mayumba
# Processing Record 211 | umzimvubu
# City not found.  Skipping...
# Processing Record 212 | solsvik
# City not found.  Skipping...
# Processing Record 213 | beringovskiy
# Processing Record 214 | college
# Processing Record 215 | golden gate
# Processing Record 216 | broumov
# Processing Record 217 | saint-francois
# Processing Record 218 | clyde river
# Processing Record 219 | cayenne
# Processing Record 220 | barraute
# Processing Record 221 | manati
# Processing Record 222 | kuldiga
# Processing Record 223 | banff
# Processing Record 224 | adrar
# Processing Record 225 | port hedland
# Processing Record 226 | ayan
# Processing Record 227 | darhan
# Processing Record 228 | kidal
# Processing Record 229 | ardesen
# Processing Record 230 | poum
# Processing Record 231 | rio grande
# Processing Record 232 | tsiroanomandidy
# Processing Record 233 | northam
# Processing Record 234 | vardo
# Processing Record 235 | chokurdakh
# Processing Record 236 | el alto
# Processing Record 237 | saint-pierre
# Processing Record 238 | bengkulu
# City not found.  Skipping...
# Processing Record 239 | belmonte
# Processing Record 240 | kupang
# Processing Record 241 | caravelas
# Processing Record 242 | kesova gora
# Processing Record 243 | tumannyy
# City not found.  Skipping...
# Processing Record 244 | yakima
# Processing Record 245 | ituni
# City not found.  Skipping...
# Processing Record 246 | kilrush
# Processing Record 247 | flinders
# Processing Record 248 | los llanos de aridane
# Processing Record 249 | cap malheureux
# Processing Record 250 | brae
# Processing Record 251 | bandarbeyla
# Processing Record 252 | saint-louis
# Processing Record 253 | angoche
# Processing Record 254 | narsaq
# Processing Record 255 | galesong
# Processing Record 256 | tazovskiy
# Processing Record 257 | kholm
# Processing Record 258 | dolbeau
# City not found.  Skipping...
# Processing Record 259 | takaishi
# Processing Record 260 | sobolevo
# Processing Record 261 | iquitos
# Processing Record 262 | padang
# Processing Record 263 | sao joao da barra
# Processing Record 264 | verkhnevilyuysk
# Processing Record 265 | belle fourche
# Processing Record 266 | halalo
# City not found.  Skipping...
# Processing Record 267 | longyearbyen
# Processing Record 268 | meyungs
# City not found.  Skipping...
# Processing Record 269 | nikel
# Processing Record 270 | yermakovskoye
# Processing Record 271 | champerico
# Processing Record 272 | yellowknife
# Processing Record 273 | coquimbo
# Processing Record 274 | waingapu
# Processing Record 275 | palahanan
# City not found.  Skipping...
# Processing Record 276 | tshela
# Processing Record 277 | portland
# Processing Record 278 | eresos
# Processing Record 279 | sao leopoldo
# Processing Record 280 | vestmannaeyjar
# Processing Record 281 | nanortalik
# Processing Record 282 | brewster
# Processing Record 283 | mundo nuevo
# Processing Record 284 | lautaro
# Processing Record 285 | naze
# Processing Record 286 | nome
# Processing Record 287 | usevya
# City not found.  Skipping...
# Processing Record 288 | auki
# Processing Record 289 | tasbuget
# City not found.  Skipping...
# Processing Record 290 | portobelo
# Processing Record 291 | sinnamary
# Processing Record 292 | carbonia
# Processing Record 293 | leningradskiy
# Processing Record 294 | rawannawi
# City not found.  Skipping...
# Processing Record 295 | daman
# Processing Record 296 | maribo
# Processing Record 297 | neepawa
# Processing Record 298 | broken hill
# Processing Record 299 | sterling
# Processing Record 300 | axim
# Processing Record 301 | dingle
# Processing Record 302 | kapoeta
# City not found.  Skipping...
# Processing Record 303 | gotsu
# Processing Record 304 | talnakh
# Processing Record 305 | casablanca
# Processing Record 306 | saldanha
# Processing Record 307 | ilanskiy
# Processing Record 308 | gumdag
# Processing Record 309 | sabaudia
# Processing Record 310 | moose factory
# Processing Record 311 | nikolayevka
# Processing Record 312 | amga
# Processing Record 313 | sabang
# Processing Record 314 | mar del plata
# Processing Record 315 | erzin
# Processing Record 316 | palmer
# Processing Record 317 | bud
# Processing Record 318 | bayonne
# Processing Record 319 | qaqortoq
# Processing Record 320 | margate
# Processing Record 321 | sangre grande
# Processing Record 322 | bakchar
# Processing Record 323 | peristera
# Processing Record 324 | port augusta
# Processing Record 325 | mys shmidta
# City not found.  Skipping...
# Processing Record 326 | port pirie
# Processing Record 327 | gloversville
# Processing Record 328 | baculin
# Processing Record 329 | ambon
# Processing Record 330 | nago
# Processing Record 331 | moundou
# Processing Record 332 | rosario do sul
# Processing Record 333 | maun
# Processing Record 334 | high level
# Processing Record 335 | eskasem
# City not found.  Skipping...
# Processing Record 336 | vila
# Processing Record 337 | yerofey pavlovich
# Processing Record 338 | atambua
# Processing Record 339 | dibaya
# City not found.  Skipping...
# Processing Record 340 | khowst
# City not found.  Skipping...
# Processing Record 341 | rancho palos verdes
# Processing Record 342 | sayyan
# Processing Record 343 | karkaralinsk
# City not found.  Skipping...
# Processing Record 344 | vila velha
# Processing Record 345 | dongying
# Processing Record 346 | victoria
# Processing Record 347 | lixourion
# Processing Record 348 | talakan
# Processing Record 349 | port moresby
# Processing Record 350 | kyrylivka
# Processing Record 351 | provideniya
# Processing Record 352 | bagan
# Processing Record 353 | liverpool
# Processing Record 354 | saleaula
# City not found.  Skipping...
# Processing Record 355 | yuanping
# Processing Record 356 | isangel
# Processing Record 357 | chicama
# Processing Record 358 | najran
# Processing Record 359 | codrington
# Processing Record 360 | revelstoke
# Processing Record 361 | syracuse
# Processing Record 362 | missoula
# Processing Record 363 | melbourne
# Processing Record 364 | orangeburg
# Processing Record 365 | port blair
# Processing Record 366 | constitucion
# Processing Record 367 | svetlogorsk
# Processing Record 368 | fayetteville
# Processing Record 369 | acajutla
# Processing Record 370 | yeniseysk
# Processing Record 371 | pevek
# Processing Record 372 | grand gaube
# Processing Record 373 | presque isle
# Processing Record 374 | toamasina
# Processing Record 375 | ercis
# Processing Record 376 | mago
# Processing Record 377 | turukhansk
# Processing Record 378 | ntcheu
# Processing Record 379 | khonuu
# City not found.  Skipping...
# Processing Record 380 | ancud
# Processing Record 381 | nurota
# Processing Record 382 | talara
# Processing Record 383 | manokwari
# Processing Record 384 | ust-ishim
# Processing Record 385 | warri
# Processing Record 386 | touros
# Processing Record 387 | asfi
# City not found.  Skipping...
# Processing Record 388 | kitimat
# Processing Record 389 | mackay
# Processing Record 390 | misratah
# Processing Record 391 | zavitinsk
# Processing Record 392 | solnechnyy
# Processing Record 393 | vanimo
# Processing Record 394 | sandy bay
# Processing Record 395 | lebu
# Processing Record 396 | khakhea
# Processing Record 397 | murdochville
# Processing Record 398 | macaboboni
# City not found.  Skipping...
# Processing Record 399 | miura
# Processing Record 400 | sokolo
# Processing Record 401 | tsihombe
# City not found.  Skipping...
# Processing Record 402 | hofn
# Processing Record 403 | brookings
# Processing Record 404 | roald
# Processing Record 405 | miri
# Processing Record 406 | ushtobe
# Processing Record 407 | wajima
# Processing Record 408 | nyurba
# Processing Record 409 | camapua
# Processing Record 410 | namibe
# Processing Record 411 | red deer
# Processing Record 412 | evensk
# Processing Record 413 | abu zabad
# Processing Record 414 | lengshuijiang
# Processing Record 415 | fortuna
# Processing Record 416 | tromso
# Processing Record 417 | rio gallegos
# Processing Record 418 | yumen
# Processing Record 419 | buala
# Processing Record 420 | nhulunbuy
# Processing Record 421 | kavieng
# Processing Record 422 | daru
# Processing Record 423 | vanino
# Processing Record 424 | huzhou
# Processing Record 425 | vao
# Processing Record 426 | suntar
# Processing Record 427 | litovko
# Processing Record 428 | ongandjera
# Processing Record 429 | matagami
# Processing Record 430 | savino
# Processing Record 431 | lasa
# Processing Record 432 | la macarena
# Processing Record 433 | ust-ilimsk
# Processing Record 434 | nemuro
# Processing Record 435 | kwinana
# Processing Record 436 | sabha
# Processing Record 437 | port hawkesbury
# Processing Record 438 | taoudenni
# Processing Record 439 | grootfontein
# Processing Record 440 | arlit
# Processing Record 441 | hamilton
# Processing Record 442 | afgoye
# City not found.  Skipping...
# Processing Record 443 | vostok
# Processing Record 444 | banda aceh
# Processing Record 445 | san patricio
# Processing Record 446 | muli
# Processing Record 447 | sao filipe
# Processing Record 448 | dzhusaly
# City not found.  Skipping...
# Processing Record 449 | staryy nadym
# Processing Record 450 | las palmas
# Processing Record 451 | dunedin
# Processing Record 452 | mergui
# City not found.  Skipping...
# Processing Record 453 | huarmey
# Processing Record 454 | anadyr
# Processing Record 455 | kloulklubed
# Processing Record 456 | zambezi
# Processing Record 457 | youghal
# Processing Record 458 | koluszki
# Processing Record 459 | graaff-reinet
# Processing Record 460 | kenora
# Processing Record 461 | sechura
# Processing Record 462 | demirci
# Processing Record 463 | dolgoye
# Processing Record 464 | takoradi
# Processing Record 465 | dalbandin
# Processing Record 466 | marsh harbour
# Processing Record 467 | aflu
# City not found.  Skipping...
# Processing Record 468 | kaeo
# Processing Record 469 | camacha
# Processing Record 470 | ternate
# Processing Record 471 | whitecourt
# Processing Record 472 | zhigansk
# Processing Record 473 | upata
# Processing Record 474 | imeni poliny osipenko
# Processing Record 475 | luebo
# Processing Record 476 | beyla
# Processing Record 477 | kahului
# Processing Record 478 | mandalgovi
# Processing Record 479 | malpura
# Processing Record 480 | tessalit
# Processing Record 481 | hayden
# Processing Record 482 | sofiysk
# City not found.  Skipping...
# Processing Record 483 | swan hill
# Processing Record 484 | adre
# Processing Record 485 | seoni
# Processing Record 486 | kirillov
# Processing Record 487 | nola
# Processing Record 488 | bilibino
# Processing Record 489 | sola
# Processing Record 490 | rocha
# Processing Record 491 | brasilia
# Processing Record 492 | kurilsk
# Processing Record 493 | hami
# Processing Record 494 | paamiut
# Processing Record 495 | nyrob
# Processing Record 496 | ardakan
# Processing Record 497 | mount gambier
# Processing Record 498 | surenavan
# Processing Record 499 | cabedelo
# Processing Record 500 | labutta
# City not found.  Skipping...
# Processing Record 501 | seminole
# Processing Record 502 | gamba
# Processing Record 503 | sioux lookout
# Processing Record 504 | harlingen
# Processing Record 505 | pilar
# Processing Record 506 | ugoofaaru
# Processing Record 507 | lozuvatka
# Processing Record 508 | usak
# Processing Record 509 | san quintin
# Processing Record 510 | shimoda
# Processing Record 511 | banjarmasin
# Processing Record 512 | muisne
# Processing Record 513 | mehamn
# Processing Record 514 | mongar
# Processing Record 515 | saint-georges
# Processing Record 516 | wynyard
# Processing Record 517 | bilma
# Processing Record 518 | marcona
# City not found.  Skipping...
# Processing Record 519 | asamankese
# Processing Record 520 | geraldton
# Processing Record 521 | vrangel
# Processing Record 522 | touho
# Processing Record 523 | gornyy
# Processing Record 524 | sidi ali
# Processing Record 525 | abeche
# Processing Record 526 | shubarkuduk
# Processing Record 527 | bereda
# Processing Record 528 | inhambane
# Processing Record 529 | jabiru
# City not found.  Skipping...
# Processing Record 530 | concarneau
# Processing Record 531 | kawana waters
# City not found.  Skipping...
# Processing Record 532 | olafsvik
# City not found.  Skipping...
# Processing Record 533 | general pico
# Processing Record 534 | vallenar
# Processing Record 535 | faya
# Processing Record 536 | klaksvik
# Processing Record 537 | soyo
# Processing Record 538 | gardez
# Processing Record 539 | fevralsk
# City not found.  Skipping...
# Processing Record 540 | hovd
# Processing Record 541 | sorochinsk
# Processing Record 542 | santa rosa
# Processing Record 543 | abatskoye
# Processing Record 544 | jining
# Processing Record 545 | leh
# Processing Record 546 | fort-shevchenko
# Processing Record 547 | gonaives
# Processing Record 548 | bargal
# City not found.  Skipping...
# Processing Record 549 | andevoranto
# City not found.  Skipping...
# Processing Record 550 | salalah
# Processing Record 551 | kismayo
# City not found.  Skipping...
# Processing Record 552 | bathsheba
# Processing Record 553 | keti bandar
# Processing Record 554 | velika gorica
# Processing Record 555 | bratsk
# Processing Record 556 | alice springs
# Processing Record 557 | snyder
# Processing Record 558 | surt
# Processing Record 559 | vaitape
# Processing Record 560 | nantucket
# Processing Record 561 | marawi
# Processing Record 562 | kununurra
# Processing Record 563 | shipitsyno
# Processing Record 564 | yarkovo
# Processing Record 565 | barranca
# Processing Record 566 | lagunas
# Processing Record 567 | noumea
# Processing Record 568 | mahadday weyne
# City not found.  Skipping...
# Processing Record 569 | palabuhanratu
# City not found.  Skipping...
# Processing Record 570 | vanavara
# Processing Record 571 | kalmunai
# Processing Record 572 | sistranda
# Processing Record 573 | shingu
# Processing Record 574 | reconquista
# Processing Record 575 | severo-kurilsk
# Processing Record 576 | calategas
# City not found.  Skipping...
# Processing Record 577 | cururupu
# Processing Record 578 | novoagansk
# Processing Record 579 | tonj
# City not found.  Skipping...
# Processing Record 580 | north bend
# Processing Record 581 | srednekolymsk
# Processing Record 582 | palafrugell
# Processing Record 583 | gazanjyk
# Processing Record 584 | sakakah
# City not found.  Skipping...
# Processing Record 585 | avera
# Processing Record 586 | santarem
# City not found.  Skipping...
# Processing Record 587 | ust-kamchatsk
# City not found.  Skipping...
# Processing Record 588 | maragogi
# Processing Record 589 | mackenzie
# Processing Record 590 | sinkat
# City not found.  Skipping...
# Processing Record 591 | fengrun
# Processing Record 592 | port lavaca
# Processing Record 593 | sault sainte marie
# Processing Record 594 | abu samrah
# Processing Record 595 | molo
# Processing Record 596 | kamenka
# Processing Record 597 | vilcun
# Processing Record 598 | satitoa
# City not found.  Skipping...
# Processing Record 599 | whitehorse
# Processing Record 600 | saint-ambroise
# Processing Record 601 | kadhan
# Processing Record 602 | karaul
# City not found.  Skipping...
# Processing Record 603 | longlac
# City not found.  Skipping...
# Processing Record 604 | miajadas
# Processing Record 605 | hangu
# Processing Record 606 | chik
# Processing Record 607 | porto nacional
# Processing Record 608 | suixi
# Processing Record 609 | grand river south east
# City not found.  Skipping...
# Processing Record 610 | mount isa
# Processing Record 611 | skalistyy
# City not found.  Skipping...
# Processing Record 612 | gloucester
# Processing Record 613 | lukovetskiy
# Processing Record 614 | tornio
# Processing Record 615 | samalaeulu
# City not found.  Skipping...
# Processing Record 616 | matara
# Processing Record 617 | santa fe
# Processing Record 618 | mocambique
# City not found.  Skipping...
# ---------------------------
#    Data retrieval Complete
# ---------------------------
#          cityName longitude latitude temperature humidity cloudiness windSpeed
# 0            chuy    -53.46   -33.69       64.04       92         12      5.73
# 1         yakeshi    120.73    49.28       32.09       57         68      15.9
# 2  guerrero negro   -114.04    27.97       67.46       57          8     11.77
# 3            hilo   -155.08    19.71        80.6       61         20     12.75
# 4           baylo    126.06     7.85       76.91       80         32       3.6

# %%
cityList.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 619 entries, 0 to 618
# Data columns (total 7 columns):
# cityName       619 non-null object
# longitude      619 non-null object
# latitude       619 non-null object
# temperature    619 non-null object
# humidity       619 non-null object
# cloudiness     619 non-null object
# windSpeed      619 non-null object
# dtypes: object(7)
# memory usage: 33.9+ KB

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cityList["longitude"].replace("",np.nan,inplace=True)
cleanList = cityList.dropna()

cleanList = cleanList.set_index("cityName")
cleanList = cleanList.astype(float)
cleanList.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 542 entries, chuy to santa fe
# Data columns (total 6 columns):
# longitude      542 non-null float64
# latitude       542 non-null float64
# temperature    542 non-null float64
# humidity       542 non-null float64
# cloudiness     542 non-null float64
# windSpeed      542 non-null float64
# dtypes: float64(6)
# memory usage: 29.6+ KB

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(cleanList["latitude"],cleanList["temperature"],marker="o")
plt.xlim(-90,90)
plt.title("City Latitude vs. Max Temperature (4/3/2019)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature(F)")
plt.grid()
plt.savefig("LatVSTemp.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(cleanList["latitude"],cleanList["humidity"],marker="o")
plt.xlim(-90,90)
plt.title("City Latitude vs. Humidity (4/3/2019)")
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")
plt.grid()
plt.savefig("LatVSHumid.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(cleanList["latitude"],cleanList["cloudiness"],marker="o")
plt.xlim(-90,90)
plt.title("City Latitude vs. Cloudiness (4/3/2019)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
plt.grid()
plt.savefig("LatVSCloud.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(cleanList["latitude"],cleanList["windSpeed"],marker="o")
plt.xlim(-90,90)
plt.title("City Latitude vs. Wind Speed (4/3/2019)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed(mph)")
plt.grid()
plt.savefig("LatVSWind.png")
plt.show()
